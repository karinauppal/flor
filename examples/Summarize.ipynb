# %%
# %load_ext autoreload
# %autoreload 2

# %%
import flor

# %%
flor.Experiment('twitter_demo').summarize()
# Out:
#                  label  alpha  frac  seed  \
# 0  2018-10-21_03-04-38    0.0  0.75    42
# 1  2018-10-21_03-04-38    1.0  0.75    42
# 2  2018-10-21_03-04-15    1.0  0.75    42
# 3  2018-10-21_03-04-15    0.0  0.75    42
# 4  2018-10-20_21-39-37    0.0  0.75    42
# 5  2018-10-20_21-39-37    1.0  0.75    42
#
#                               tweet_df                      model_accuracy  \
# 0  training_tweets_139985749376808.pkl  model_accuracy_139985749375520.txt
# 1  training_tweets_139985749376808.pkl  model_accuracy_139985749376920.txt
# 2  training_tweets_139986078499504.pkl  model_accuracy_139986814896224.txt
# 3  training_tweets_139986078499504.pkl  model_accuracy_139986814895720.txt
# 4  training_tweets_140689539276304.pkl  model_accuracy_140689539276248.txt
# 5  training_tweets_140689539276304.pkl  model_accuracy_140689539273224.txt
#
#                               test_df               intermediary  \
# 0  testing_tweets_139985749375688.pkl  model_139985749376248.pkl
# ...
